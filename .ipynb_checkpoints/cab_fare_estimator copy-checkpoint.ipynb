# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
import joblib
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("delhi_cab_fare_mock_dataset.csv")

# %%
df.head(5)
# Out:
#    pickup_location   drop_location  distance_km  duration_min  hour  \
# 0            Saket  Rajouri Garden         6.56          17.2    13
# 1  Connaught Place   Chandni Chowk        19.53          65.7     1
# 2        Pitampura           Saket        18.92          69.4    17
# 3           Dwarka           Saket        17.51          52.3     8
# 4  Connaught Place   Chandni Chowk        23.90          86.6     8
#
#    dayofweek  is_weekend  temperature weather_condition  fare_amount
# 0          0           0         32.2            Clouds       135.92
# 1          6           1         41.2            Clouds       340.06
# 2          3           0         33.4            Clouds       386.91
# 3          0           0         20.7               Fog       347.78
# 4          4           0         30.5      Thunderstorm       570.49

# %%
df.describe()
# Out:
#        distance_km  duration_min        hour   dayofweek  is_weekend  \
# count   500.000000    500.000000  500.000000  500.000000  500.000000
# mean     14.107340     42.369000   11.658000    3.090000    0.324000
# std       6.352196     21.207491    6.630608    2.038188    0.468469
# min       3.000000      6.300000    0.000000    0.000000    0.000000
# 25%       8.615000     25.150000    6.000000    1.000000    0.000000
# 50%      13.980000     40.100000   12.000000    3.000000    0.000000
# 75%      19.807500     57.100000   17.000000    5.000000    1.000000
# max      24.990000     99.600000   23.000000    6.000000    1.000000
#
#        temperature  fare_amount
# count   500.000000   500.000000
# mean     30.241400   278.887260
# std       6.976765   111.582978
# min      18.000000    84.340000
# 25%      23.900000   189.970000
# 50%      30.800000   273.340000
# 75%      36.300000   363.955000
# max      41.900000   581.890000

# %%
df.isnull().sum()
# Out:
# pickup_location      0
# drop_location        0
# distance_km          0
# duration_min         0
# hour                 0
# dayofweek            0
# is_weekend           0
# temperature          0
# weather_condition    0
# fare_amount          0
# dtype: int64

# %%
df['weather_condition'].unique()
# Out:
# array(['Clouds', 'Fog', 'Thunderstorm', 'Clear', 'Haze', 'Rain'],
#       dtype=object)

# %%
X=df.drop(columns=['pickup_location','drop_location','fare_amount'])
y=df['fare_amount']

# %%
preprocessor = ColumnTransformer([("weather", OneHotEncoder(), ["weather_condition"])], remainder='passthrough')

# %%
model = Pipeline([
    ("preprocess", preprocessor),
    ("regressor", RandomForestRegressor(n_estimators=100, random_state=42))
])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
model.fit(X_train, y_train)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/compose/_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('weather', OneHotEncoder(),
#                                                   ['weather_condition'])])),
#                 ('regressor', RandomForestRegressor(random_state=42))])

# %%
joblib.dump(model, "cab_fare_model.pkl")
# Out:
# ['cab_fare_model.pkl']
